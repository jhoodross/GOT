# %%
# !pip install opendatasets

# %%
import opendatasets as od

# %%
dataset = 'https://www.kaggle.com/datasets/mylesoneill/game-of-thrones'

# %%
od.download(dataset)
# Out:
# Skipping, found downloaded files in ".\game-of-thrones" (use force=True to force download)

# %%
import os

# %%
data_dir = '.\game-of-thrones'

# %%
os.listdir(data_dir)
# Out:
# ['.ipynb_checkpoints']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df_battle = pd.read_csv('battles.csv')
df_char_death = pd.read_csv('character-deaths.csv')
df_char_prediction = pd.read_csv('character-predictions.csv')

# %%
df_battle.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1 defender_2  defender_3  defender_4  \
# 0        NaN        NaN      Tully        NaN         NaN         NaN
# ...

# %%
df_battle.hist(figsize=(10,20))
# Out:
# array([[<AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'battle_number'}>,
#         <AxesSubplot:title={'center':'defender_3'}>],
#        [<AxesSubplot:title={'center':'defender_4'}>,
#         <AxesSubplot:title={'center':'major_death'}>,
#         <AxesSubplot:title={'center':'major_capture'}>],
#        [<AxesSubplot:title={'center':'attacker_size'}>,
#         <AxesSubplot:title={'center':'defender_size'}>,
#         <AxesSubplot:title={'center':'summer'}>]], dtype=object)

# %%
df_battle.isna().sum()
# Out:
# name                   0
# year                   0
# battle_number          0
# attacker_king          2
# defender_king          3
# attacker_1             0
# attacker_2            28
# attacker_3            35
# attacker_4            36
# defender_1             1
# defender_2            36
# defender_3            38
# defender_4            38
# attacker_outcome       1
# battle_type            1
# major_death            1
# major_capture          1
# attacker_size         14
# defender_size         19
# attacker_commander     1
# defender_commander    10
# summer                 1
# location               1
# region                 0
# note                  33
# dtype: int64

# %%
df_battle.shape
# Out:
# (38, 25)

# %%
df_battle
# Out:
#                                                  name  year  battle_number  \
# 0                          Battle of the Golden Tooth   298              1
# 1                         Battle at the Mummer's Ford   298              2
# 2                                  Battle of Riverrun   298              3
# 3                            Battle of the Green Fork   298              4
# 4                       Battle of the Whispering Wood   298              5
# 5                                 Battle of the Camps   298              6
# 6                                       Sack of Darry   298              7
# 7                               Battle of Moat Cailin   299              8
# 8                            Battle of Deepwood Motte   299              9
# 9                           Battle of the Stony Shore   299             10
# 10                         Battle of Torrhen's Square   299             11
# ...

# %%
df_battle['battle_type'].value_counts()
# Out:
# pitched battle    14
# siege             11
# ambush            10
# razing             2
# Name: battle_type, dtype: int64

# %%
df_battle['attacker_1'].value_counts()
# Out:
# Lannister                      8
# Stark                          8
# Greyjoy                        7
# Baratheon                      6
# Bolton                         2
# Frey                           2
# Darry                          1
# Brotherhood without Banners    1
# Free folk                      1
# Brave Companions               1
# Bracken                        1
# Name: attacker_1, dtype: int64

# %%
df_battle['attacker_1'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_battle['year'].value_counts()
# Out:
# 299    20
# 300    11
# 298     7
# Name: year, dtype: int64

# %%
df_battle['defender_1'].value_counts()
# Out:
# Lannister           9
# Stark               8
# Tully               4
# Baratheon           4
# Greyjoy             3
# Brave Companions    2
# Tyrell              2
# Darry               1
# Mallister           1
# Night's Watch       1
# Blackwood           1
# Bolton              1
# Name: defender_1, dtype: int64

# %%
attacker_win_percent = df_battle[['attacker_1', 'attacker_outcome']].value_counts()
attacker_win_percent
# Out:
# attacker_1                   attacker_outcome
# Greyjoy                      win                 7
# Lannister                    win                 7
# Stark                        win                 6
# Baratheon                    win                 4
# Bolton                       win                 2
# Frey                         win                 2
# Stark                        loss                2
# Baratheon                    loss                1
# Bracken                      win                 1
# Brave Companions             win                 1
# Brotherhood without Banners  win                 1
# Darry                        win                 1
# Free folk                    loss                1
# Lannister                    loss                1
# dtype: int64

# %%
df_battle['attacker_outcome'].value_counts()
attacker_win = []
attacker_loss = []

for x in df_battle['attacker_outcome']:
    if x == 'win':
        attacker_win.append(x)
    else:
        attacker_loss.append(x)

print('Attacker Win:', enumerate(attacker_win))
print('Attacker Loss:', enumerate(attacker_loss))
# Out:
# Attacker Win: <enumerate object at 0x000001E37CA23300>
# Attacker Loss: <enumerate object at 0x000001E37CA23300>

# %%
df_battle['attacker_outcome'].value_counts()
# Out:
# win     32
# loss     5
# Name: attacker_outcome, dtype: int64

# %%
df_battle.columns
# Out:
# Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#        'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#        'defender_2', 'defender_3', 'defender_4', 'attacker_outcome',
#        'battle_type', 'major_death', 'major_capture', 'attacker_size',
#        'defender_size', 'attacker_commander', 'defender_commander', 'summer',
#        'location', 'region', 'note'],
#       dtype='object')

# %%
plt.figure(figsize=(20,8))
sns.countplot(df_battle['attacker_outcome'])
# Out:
# <AxesSubplot:xlabel='attacker_outcome', ylabel='count'>

# %%
pd.crosstab(df_battle['attacker_1'], df_battle['attacker_outcome']).plot(kind='bar', figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='attacker_1'>

# %%
df_battle.columns
# Out:
# Index(['name', 'year', 'battle_number', 'attacker_king', 'defender_king',
#        'attacker_1', 'attacker_2', 'attacker_3', 'attacker_4', 'defender_1',
#        'defender_2', 'defender_3', 'defender_4', 'attacker_outcome',
#        'battle_type', 'major_death', 'major_capture', 'attacker_size',
#        'defender_size', 'attacker_commander', 'defender_commander', 'summer',
#        'location', 'region', 'note'],
#       dtype='object')

# %%
plt.figure(figsize=(20,8))
sns.countplot(df_battle['attacker_commander'],hue=df_battle['battle_type']);
plt.xticks(rotation=90);
# Out:
# C:\Users\jkhro\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pd.crosstab(df_battle['attacker_1'], df_battle['battle_type']).plot(kind='bar', figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='attacker_1'>
